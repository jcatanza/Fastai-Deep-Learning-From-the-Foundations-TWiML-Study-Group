# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
#export
from exp.nb_10c import *

# %%
# torchviz for visualizing neural networks
# first install in your fastai environment, with `pip install torchviz`
from torchviz import make_dot

# %% [markdown]
# ## Imagenet(te) training

# %% [markdown]
# [Jump_to lesson 12 video](https://course.fast.ai/videos/?lesson=12&t=1681)

# %%
path = datasets.untar_data(datasets.URLs.IMAGENETTE_160)

# %%
size = 128
tfms = [make_rgb, RandomResizedCrop(size, scale=(0.35,1)), np_to_float, PilRandomFlip()]

bs = 64

il = ImageList.from_files(path, tfms=tfms)
sd = SplitData.split_by_func(il, partial(grandparent_splitter, valid_name='val'))
ll = label_by_func(sd, parent_labeler, proc_y=CategoryProcessor())

ll.valid.x.tfms = [make_rgb, CenterCrop(size), np_to_float]

data = ll.to_databunch(bs, c_in=3, c_out=10, num_workers=8)

# %% [markdown]
# ## XResNet

# %% [markdown]
# [Jump_to lesson 12 video](https://course.fast.ai/videos/?lesson=12&t=1701)

# %%
#export
def noop(x): return x

# convert image to vector for each channel, so output is of size (n_batch,n_channels)
class Flatten(nn.Module):
    def forward(self, x): return x.view(x.size(0), -1)

# preset all but ni and nf inputs to Conv2d: ks=3 stride=1, bias = False
#      ks is the kernel size of the convolution filter
def conv(ni, nf, ks=3, stride=1, bias=False):
    return nn.Conv2d(ni, nf, kernel_size=ks, stride=stride, padding=ks//2, bias=bias)

# %%
#export

# set activation function
act_fn = nn.ReLU(inplace=True)

# initialize a cnn
def init_cnn(m):
    # initialize bias to if 'bias' is not None
    if getattr(m, 'bias', None) is not None: nn.init.constant_(m.bias, 0)
    # if the model is a convolution or linear layer, do kaiming initialization of weights
    if isinstance(m, (nn.Conv2d,nn.Linear)): nn.init.kaiming_normal_(m.weight)
    # recursively apply init_cnn to all children
    for l in m.children(): init_cnn(l)

# make a convolution layer, consisting of a convolution, a batchnorm, and optionally an activation function
def conv_layer(ni, nf, ks=3, stride=1, zero_bn=False, act=True):
    bn = nn.BatchNorm2d(nf)
    nn.init.constant_(bn.weight, 0. if zero_bn else 1.)
    layers = [conv(ni, nf, ks, stride=stride), bn]
    if act: layers.append(act_fn)
    return nn.Sequential(*layers)

# %%
#export
class ResBlock(nn.Module):
    # expansion = 1 for resnet 18 and 34
    # expansion = 4 for resnet 50, 101, and 152
    def __init__(self, expansion, ni, nh, stride=1):
        super().__init__()
        nf,ni = nh*expansion,ni*expansion
        # 2 layers for resnet 18 and 43; 3 layers for resnet 50, 101, 152
        # final layer has batchnorm weights initialized to zero and no activation
        layers  = [conv_layer(ni, nh, 3, stride=stride),
                   conv_layer(nh, nf, 3, zero_bn=True, act=False)
        ] if expansion == 1 else [
                   conv_layer(ni, nh, 1),
                   conv_layer(nh, nh, 3, stride=stride),
                   conv_layer(nh, nf, 1, zero_bn=True, act=False)
        ]
        self.convs = nn.Sequential(*layers)
        self.idconv = noop if ni==nf else conv_layer(ni, nf, 1, act=False)
        self.pool = noop if stride==1 else nn.AvgPool2d(2, ceil_mode=True)

    def forward(self, x): return act_fn(self.convs(x) + self.idconv(self.pool(x)))

# %%
#export
class XResNet(nn.Sequential):
    @classmethod
    def create(cls, expansion, layers, c_in=3, c_out=1000):
        nfs = [c_in, (c_in+1)*8, 64, 64]
        stem = [conv_layer(nfs[i], nfs[i+1], stride=2 if i==0 else 1)
            for i in range(3)]

        nfs = [64//expansion,64,128,256,512]
        res_layers = [cls._make_layer(expansion, nfs[i], nfs[i+1],
                                      n_blocks=l, stride=1 if i==0 else 2)
                  for i,l in enumerate(layers)]
        res = cls(
            *stem,
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
            *res_layers,
            nn.AdaptiveAvgPool2d(1), Flatten(),
            nn.Linear(nfs[-1]*expansion, c_out),
        )
        init_cnn(res)
        return res

    @staticmethod
    def _make_layer(expansion, ni, nf, n_blocks, stride):
        return nn.Sequential(
            *[ResBlock(expansion, ni if i==0 else nf, nf, stride if i==0 else 1)
              for i in range(n_blocks)])

# %%
#export
def xresnet18 (**kwargs): return XResNet.create(1, [2, 2,  2, 2], **kwargs)
def xresnet34 (**kwargs): return XResNet.create(1, [3, 4,  6, 3], **kwargs)
def xresnet50 (**kwargs): return XResNet.create(4, [3, 4,  6, 3], **kwargs)
def xresnet101(**kwargs): return XResNet.create(4, [3, 4, 23, 3], **kwargs)
def xresnet152(**kwargs): return XResNet.create(4, [3, 8, 36, 3], **kwargs)

# %% [markdown]
# ## Build a xresnet-18 model

# %% [markdown]
# [Jump_to lesson 12 video](https://course.fast.ai/videos/?lesson=12&t=2515)

# %%
cbfs = [partial(AvgStatsCallback,accuracy), ProgressCallback, CudaCallback,
        partial(BatchTransformXCallback, norm_imagenette),
#         partial(MixUp, alpha=0.2)
       ]

# %%
loss_func = LabelSmoothingCrossEntropy()
arch = partial(xresnet18, c_out=10)
opt_func = adam_opt(mom=0.9, mom_sqr=0.99, eps=1e-6, wd=1e-2)

# %%
#export
def get_batch(dl, learn):
    learn.xb,learn.yb = next(iter(dl))
    learn.do_begin_fit(0)
    learn('begin_batch')
    learn('after_fit')
    return learn.xb,learn.yb

# %% [markdown]
# We need to replace the old `model_summary` since it used to take a `Runner`.

# %%
# export
def model_summary(model, data, find_all=False, print_mod=False):
    xb,yb = get_batch(data.valid_dl, learn)
    mods = find_modules(model, is_lin_layer) if find_all else model.children()
    f = lambda hook,mod,inp,out: print(f"====\n{mod}\n" if print_mod else "", out.shape)
    with Hooks(mods, f) as hooks: learn.model(xb)

# %%
learn = Learner(arch(), data, loss_func, lr=1, cb_funcs=cbfs, opt_func=opt_func)

# %% [markdown]
# ## Visualize the model architecture

# %%
learn.model_cpu = learn.model.cpu()

# %%
model_summary(learn.model, data, print_mod=False)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
#  torch.Size([128, 32, 64, 64])
#  torch.Size([128, 64, 64, 64])
#  torch.Size([128, 64, 64, 64])
#  torch.Size([128, 64, 32, 32])
#  torch.Size([128, 64, 32, 32])
#  torch.Size([128, 128, 16, 16])
#  torch.Size([128, 256, 8, 8])
#  torch.Size([128, 512, 4, 4])
#  torch.Size([128, 512, 1, 1])
#  torch.Size([128, 512])
#  torch.Size([128, 10])

# %%
# visualize the model architecture
model = learn.model_cpu
x = torch.randn([1, 3, 128, 128])
graph = make_dot(model(x), params=dict(model.named_parameters()))
graph.format = 'png'
graph.render('bn')
graph

# %% [markdown]
# ## Build an xresnet-34 model and determine a good learning rate

# %%
arch = partial(xresnet34, c_out=10)

# %%
learn = Learner(arch(), data, loss_func, lr=1, cb_funcs=cbfs, opt_func=opt_func)

# %%
# empirically determine a good learning rate
learn.fit(1, cbs=[LR_Find(), Recorder()])
learn.recorder.plot(skip_last = 3)
plt.ylabel('loss')
plt.xlabel('learning rate')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# Text(0.5, 0, 'learning rate')

# %% [markdown]
# ## Create learning rate schedules

# %%
#export
# input: a number on the interval [0,1], or a list of such numbers
# output: extends the list with another number, such that all the numbers add to one
def create_phases(phases):
    phases = listify(phases)
    return phases + [1-sum(phases)]

# %%
# examples
print(create_phases(0.3))
print(create_phases([0.3,0.2]))
# Out:
# [0.3, 0.7]
# [0.3, 0.2, 0.5]

# %%
# caution: doesn't check that input is valid
#     i.e. numbers in list should be positive and should have a sum that is less than 1, 
#      so can give negative phases!!!
print(create_phases(-0.1))
print(create_phases([0.7,0.8]))
print(create_phases([0.7,0.8, 0.6]))
# Out:
# [-0.1, 1.1]
# [0.7, 0.8, -0.5]
# [0.7, 0.8, 0.6, -1.1]

# %%
# create learning rate schedules
lr = 1e-2
pct_start = 0.5
phases = create_phases(pct_start)
sched_lr  = combine_scheds(phases, cos_1cycle_anneal(lr/10., lr, lr/1e5))
sched_mom = combine_scheds(phases, cos_1cycle_anneal(0.95, 0.85, 0.95))

# %%
# create callbacks for the learning schedules
cbsched = [
    ParamScheduler('lr', sched_lr),
    ParamScheduler('mom', sched_mom)]

# %% [markdown]
# ## Train the xresnet-34 model with the learning rate schedules

# %%
# create a Learner object
learn = Learner(arch(), data, loss_func, lr=lr, cb_funcs=cbfs, opt_func=opt_func)

# %%
# train the model
learn.fit(5, cbs=cbsched)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.677569</td>
#       <td>0.501939</td>
#       <td>1.998155</td>
#       <td>0.448000</td>
#       <td>05:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.441444</td>
#       <td>0.615635</td>
#       <td>1.716789</td>
#       <td>0.510000</td>
#       <td>05:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.312632</td>
#       <td>0.666434</td>
#       <td>1.274288</td>
#       <td>0.698000</td>
#       <td>03:58</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.142816</td>
#       <td>0.736311</td>
#       <td>1.079520</td>
#       <td>0.770000</td>
#       <td>01:43</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %% [markdown]
# ## Flexible method to create a Learner

# %% [markdown]
# #### [Jump_to lesson 12 video](https://course.fast.ai/videos/?lesson=12&t=2711)

# %%
#export
def cnn_learner(arch, data, loss_func, opt_func, c_in=None, c_out=None,
                lr=1e-2, cuda=True, norm=None, progress=True, mixup=0, xtra_cb=None, **kwargs):
    cbfs = [partial(AvgStatsCallback,accuracy)]+listify(xtra_cb)
    if progress: cbfs.append(ProgressCallback)
    if cuda:     cbfs.append(CudaCallback)
    if norm:     cbfs.append(partial(BatchTransformXCallback, norm))
    if mixup:    cbfs.append(partial(MixUp, mixup))
    arch_args = {}
    if not c_in : c_in  = data.c_in
    if not c_out: c_out = data.c_out
    if c_in:  arch_args['c_in' ]=c_in
    if c_out: arch_args['c_out']=c_out
    return Learner(arch(**arch_args), data, loss_func, opt_func=opt_func, lr=lr, cb_funcs=cbfs, **kwargs)

# %% [markdown]
# ## Let's try an xresnet-18 model with the same learning rate schedules

# %%
#learn = cnn_learner(xresnet34, data, loss_func, opt_func, norm=norm_imagenette)
learn = cnn_learner(xresnet18, data, loss_func, opt_func, norm=norm_imagenette)

# %%
learn.fit(5, cbsched)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>train_accuracy</th>
#       <th>valid_loss</th>
#       <th>valid_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.688512</td>
#       <td>0.493408</td>
#       <td>1.595463</td>
#       <td>0.560000</td>
#       <td>01:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.457410</td>
#       <td>0.600512</td>
#       <td>2.376162</td>
#       <td>0.396000</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.321719</td>
#       <td>0.662168</td>
#       <td>1.241997</td>
#       <td>0.698000</td>
#       <td>01:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.145524</td>
#       <td>0.739336</td>
#       <td>1.119666</td>
#       <td>0.740000</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %% [markdown]
# ## Imagenet

# %% [markdown]
# You can see all this put together in the fastai [imagenet training script](https://github.com/fastai/fastai/blob/master/examples/train_imagenet.py). It's the same as what we've seen so far, except it also handles multi-GPU training. So how well does this work?
#
# We trained for 60 epochs, and got an error of 5.9%, compared to the official PyTorch resnet which gets 7.5% error in 90 epochs! Our xresnet 50 training even surpasses standard resnet 152, which trains for 50% more epochs and has 3x as many layers.

# %% [markdown]
# ## Export

# %%
# !python notebook2script.py 11_train_imagenette.ipynb
